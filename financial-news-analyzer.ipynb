# %%
# Install all necessary packages
# !pip install psycopg2-binary spacy transformers torch sentencepiece
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1.tar.gz
# !pip install supabase

# %%
# !pip uninstall -y pyparsing
# !pip install "pyparsing==3.1.2"

# %%
import os
from supabase import create_client, Client
import spacy
from transformers import pipeline
import torch
from kaggle_secrets import UserSecretsClient

# Get the database URL from Kaggle's secret manager
user_secrets = UserSecretsClient()
SUPABASE_URL = user_secrets.get_secret("SUPABASE_URL")
SUPABASE_SERVICE_KEY = user_secrets.get_secret("SUPABASE_SERVICE_KEY")

supabase: Client = create_client(SUPABASE_URL, SUPABASE_SERVICE_KEY)

# %%
# !wget --no-check-certificate 'https://drive.google.com/uc?export=download&id=1lliKPLzQbkyg-gJpPMmTOOzwls9pJK2_' -O model-best.zip
# !unzip model-best.zip -d ./model

# %%
print("Loading models... This may take a while.")
NER_MODEL_PATH = "./model/model-best"
SENTIMENT_MODEL_NAME = "KOlCi/distilbert-financial-sentiment"

nlp_ner = None
sentiment_pipeline = None

try:
    nlp_ner = spacy.load(NER_MODEL_PATH)
    # Kaggle gives us a GPU, so we set device=0
    sentiment_pipeline = pipeline("sentiment-analysis", model=SENTIMENT_MODEL_NAME, device=0)
    print("Models loaded successfully.")
except Exception as e:
    print(f"FATAL: Could not load models. Error: {e}")

# %%
def analyze_and_save():
    if not nlp_ner or not sentiment_pipeline:
        print("Models not loaded, cannot process.")
        return

    try:
        print("Fetching new briefs from Supabase...")
        response = supabase.table('briefs').select(
            "content_hash, content"
        ).is_(
            'sentiment', 'null'
        ).limit(100).execute()

        briefs_to_process = response.data
        if not briefs_to_process:
            print("No new briefs to process.")
            return

        print(f"Found {len(briefs_to_process)} briefs to analyze.")
        
        briefs_to_update = []
        for brief in briefs_to_process:
            content_hash = brief['content_hash']
            text = brief['content']
            
            try:
                ner_doc = nlp_ner(text)
                companies = ", ".join([ent.text for ent in ner_doc.ents]) or None
                sentiment_result = sentiment_pipeline(text)
                sentiment = sentiment_result[0]['label'].upper()
                score = sentiment_result[0]['score']

                briefs_to_update.append({
                    'content_hash': content_hash, # The key to match the row
                    'content': text,
                    'subject_company': companies,
                    'sentiment': sentiment,
                    'confidence': f"{score:.4f}",
                    'processed_at': 'now()'
                })
            except Exception as e:
                print(f"Error processing item {content_hash}: {e}")

        if not briefs_to_update:
            print("Processing finished, but no briefs were successfully analyzed.")
            return

        print(f"Saving {len(briefs_to_update)} analyzed briefs back to Supabase...")
        supabase.table('briefs').upsert(
            briefs_to_update, 
            on_conflict='content_hash'
        ).execute()
        
        print(f"Processing complete. Analyzed {len(briefs_to_update)} brief(s).")

    except Exception as e:
        print(f"An API or database error occurred: {e}")

analyze_and_save()
